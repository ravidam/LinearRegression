# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %%
dataset = pd.read_csv('q2.csv')
Body = dataset.iloc[:,:-1].values
Brain = dataset.iloc[:,:1].values

# %%
plt.scatter(Body, Brain)
plt.xlabel("body weight")
plt.ylabel("brain weight")
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(StandardScaler().fit_transform(Body), Brain, test_size= 0.33, random_state= 0)

# %%
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)
error = y_test - y_pred

# %%
plt.scatter(x_train, y_train, color = 'red')
plt.plot(x_train, regressor.predict(x_train), color = 'blue')

plt.title('Body weight VS. brain weight (training set)')
plt.xlabel('body weight')
plt.ylabel('brain weight')
plt.show()

# %%
plt.scatter(x_test, y_test, color = 'red')
plt.plot(x_train, regressor.predict(x_train), color = 'blue')

plt.title('Body weight VS. brain weight (test set)')
plt.xlabel('body weight')
plt.ylabel('brain weight')
plt.show()

# %%
x = 30
y = regressor.intercept_ + (x*regressor.coef_)
print(y)
# Out:
# [[26955.10775469]]
